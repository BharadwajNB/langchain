# %% [markdown]
# ### Model Integration with OpenAI, Google Gemini and GROQ

# %%
import os 
from dotenv import load_dotenv  
load_dotenv()

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# ### Google Gemini Model Integration ###

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI( model="gemini-2.5-flash")

## invoke the model 
response = model.invoke("When is portugal next match in fifa world cup 2026?")
response
# Out:
# AIMessage(content="The FIFA World Cup 2026 is still quite a way off!\n\n**It's impossible to know Portugal's next match in the 2026 World Cup at this point for several reasons:**\n\n1.  **Qualification Hasn't Concluded (or even started for UEFA):** Portugal, like all other European nations, still needs to go through the UEFA qualification process for the 2026 World Cup. These qualifiers are expected to start in **early 2025**.\n2.  **Groups Aren't Drawn:** Even once teams qualify, the draw for the final tournament groups typically happens in **late 2025 or early 2026**.\n3.  **Tournament Schedule Unknown:** Only after the groups are drawn will the specific match dates, times, and opponents for each team be determined.\n\n**In summary: Portugal doesn't have any specific matches scheduled for the 2026 World Cup yet because they haven't qualified, and the tournament draw hasn't happened.**\n\nYou'll need to wait until late 2025 or early 2026 for that information to become available!", a
# ...

# %% [markdown]
# ### GROQ Model Integration ###

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model="llama-3.3-70b-versatile")

## invoke the model
response = model.invoke("Hello How are you?")
response
# Out:
# AIMessage(content="Hello! I'm doing well, thanks for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to help with any questions or tasks you may have. How about you? How's your day going so far?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 40, 'total_tokens': 101, 'completion_time': 0.114729451, 'completion_tokens_details': None, 'prompt_time': 0.001731057, 'prompt_tokens_details': None, 'queue_time': 0.285195177, 'total_time': 0.116460508}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_0761e44d7b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ed0df-7b9e-7243-8a8a-8f992f86cef4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 61, 'total_tokens': 101})

# %%
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content='Parrots are known for their remarkable ability to mimic human speech and other sounds, but why do they do it? The reasons behind parrot vocalizations are complex and multifaceted. Here are some possible explanations:\n\n1. **Communication and Social Bonding**: In the wild, parrots use vocalizations to communicate with their flock members, including contact calls, alarm calls, and courtship displays. By mimicking human speech, parrots may be attempting to establish a social bond with their human caregivers or to initiate interaction.\n2. **Learning and Imitation**: Parrots are highly intelligent birds, and they have a strong instinct to learn and imitate sounds they hear in their environment. They may repeat words or phrases they\'ve learned from their owners or other parrots, simply because it\'s a fun and engaging activity.\n3. **Attention Seeking**: Parrots may talk to get attention from their owners, especially if they\'ve learned that speaking leads to rewards,
# ...

# %% [markdown]
# ### Streaming and Batch ###

# %% [markdown]
# ### Streaming ###

# %%
response = model.invoke("Hey, write me a 200 words paragraph on Artificial Intelligence")
response
# Out:
# AIMessage(content='Artificial Intelligence (AI) has revolutionized the way we live and work, transforming numerous aspects of our daily lives. From virtual assistants like Siri and Alexa to self-driving cars and personalized product recommendations, AI has become an integral part of our technological landscape. At its core, AI refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. Machine learning, a subset of AI, enables systems to learn from data and improve their performance over time, making them increasingly sophisticated. The applications of AI are vast and varied, ranging from healthcare and finance to education and transportation. As AI continues to evolve and advance, we can expect to see even more innovative solutions that enhance our productivity, efficiency, and overall quality of life. With its potential to drive significant economic growth and improve societa
# ...

# %%
model.invoke("write me a 200 words paragraph on Artificial Intelligence")
# Out:
# AIMessage(content='Artificial Intelligence (AI) has revolutionized the way we live, work, and interact with technology. AI refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. From virtual assistants like Siri and Alexa to self-driving cars and personalized product recommendations, AI is increasingly becoming an integral part of our daily lives. AI algorithms can analyze vast amounts of data, identify patterns, and make predictions, enabling businesses to make informed decisions and improve their operations. Additionally, AI-powered chatbots and virtual agents are being used in customer service to provide 24/7 support and enhance user experience. The potential applications of AI are vast and varied, ranging from healthcare and education to finance and transportation. As AI technology continues to advance, we can expect to see even more innovative solutions that transform
# ...

# %%
for chunk in model.stream("Why do parrots have colourful feathers?"):
    print(chunk.text, end="", flush=True)
# Out:
# Parrots have colorful feathers for several reasons, including:
#
# 1. **Communication and Expression**: Colorful feathers help parrots communicate with each other, convey emotions, and express their individuality. Different colors and patterns can signal aggression, courtship, or friendliness.
# 2. **Mating and Attraction**: Bright colors can be an attractive feature for potential mates. Parrots with more vibrant feathers may be perceived as healthier, stronger, or more desirable partners.
# 3. **Camouflage and Protection**: While parrots are known for their bright colors, some species have feathers that help them blend in with their surroundings. For example, the green feathers of some parrot species can help them hide in foliage.
# 4. **Social Status**: In some parrot species, colorful feathers can indicate social status or dominance. Birds with more vibrant or elaborate feathers may be higher in the social hierarchy.
# ...

# %% [markdown]
# ### Batch ###

# %%
responses = model.batch([
    "what is AI?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)
# Out:
# content='**Artificial Intelligence (AI)**: Artificial Intelligence refers to the development of computer systems that can perform tasks that would typically require human intelligence, such as:\n\n* Learning\n* Problem-solving\n* Reasoning\n* Perception\n* Understanding language\n\nAI involves the use of algorithms, statistical models, and computer programs to enable machines to make decisions, classify objects, and predict outcomes. The goal of AI is to create systems that can think and act like humans, or even surpass human capabilities in certain areas.\n\n**Key Types of AI:**\n\n1. **Narrow or Weak AI**: Designed to perform a specific task, such as image recognition, language translation, or playing chess.\n2. **General or Strong AI**: A hypothetical AI system that possesses human-like intelligence and can perform any intellectual task.\n3. **Superintelligence**: An AI system that significantly surpasses human intelligence and capabilities.\n\n**AI Applications:**\n\n1. **Virtual
# ...
