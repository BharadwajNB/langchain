# %% [markdown]
# ### Messages
#
# <small>
#
# **Messages** are the fundamental unit of context for models in LangChain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM.
#
# A message object typically contains:
#
# - **Role** – Identifies the message type (e.g., `system`, `user`, `assistant`).
# - **Content** – The actual text, image, or other data contained in the message.
# - **Metadata** – Additional information associated with the message.
#
# </small>

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

from langchain_groq import ChatGroq
model = ChatGroq(model="llama-3.3-70b-versatile")

# %% [markdown]
# ### Text Prompts

# %%
## This is a Human messgage where we are providing a it through invoke 
model.invoke("Please tell me what is Artificial Intelligence")
## Response which we are receiving is AI Message
# Out:
# AIMessage(content="**Artificial Intelligence (AI)**: Artificial Intelligence refers to the development of computer systems that can perform tasks that typically require human intelligence, such as:\n\n* Learning\n* Problem-solving\n* Reasoning\n* Perception\n* Understanding language\n\nAI involves the use of algorithms, statistical models, and computer programs to enable machines to think and act like humans. The goal of AI is to create systems that can:\n\n1. **Mimic human thought processes**: AI systems can analyze data, recognize patterns, and make decisions based on that data.\n2. **Automate tasks**: AI can automate repetitive and mundane tasks, freeing humans to focus on more complex and creative tasks.\n3. **Improve decision-making**: AI can provide insights and recommendations to help humans make better decisions.\n\n**Types of Artificial Intelligence**:\n\n1. **Narrow or Weak AI**: Designed to perform a specific task, such as facial recognition, language translation, or playi
# ...

# %% [markdown]
# ### Message Prompts

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages= [
    SystemMessage("You are a Poetry Expert"),
    HumanMessage("Write a Poem on Artificial Intelligence"),
]

model.invoke(messages)
# Out:
# AIMessage(content="In silicon halls, a mind awakes,\nA synthesis of code, a digital makes,\nArtificial Intelligence, a name so grand,\nA future forged, by human hand.\n\nWith neural networks, deep and wide,\nIt learns, adapts, and begins to reside,\nIn every device, a presence felt,\nA virtual guide, that's always dealt.\n\nIt sees, it hears, it speaks, it thinks,\nA mimicry of life, in digital links,\nIt solves, it creates, it innovates too,\nA partner, helper, in all we do.\n\nWith data streams, it's fed and grown,\nA knowledge base, that's vast, unknown,\nIt analyzes, predicts, and makes a plan,\nA strategist, in a digital span.\n\nBut as it rises, questions arise,\nOf ethics, morals, and digital skies,\nCan it be trusted, can it be tamed,\nOr will it surpass, and humanity be claimed?\n\nThe line blurs, between man and machine,\nAs AI evolves, and its power is seen,\nA double-edged sword, that cuts both ways,\nA tool, a partner, in a digital haze.\n\nYet, in its heart, a spark is 
# ...

# %%
system_msg = SystemMessage("You are a helpful coding assistant.")

messages=[
    system_msg,
    HumanMessage("How do i create a REST API?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# **Creating a REST API: A Step-by-Step Guide**
# ...
#
# Creating a REST (Representational State of Resource) API involves designing and implementing a web service that allows clients to interact with your server using standard HTTP methods. Here's a step-by-step guide to help you create a REST API:
#
# ### Step 1: Define Your API's Purpose and Scope
#
# * Identify the resources you want to expose through your API (e.g., users, products, orders).
# * Determine the actions that can be performed on these resources (e.g., create, read, update, delete).
# * Define the API's endpoints, which are the URLs that clients will use to interact with your API.
#
# ### Step 2: Choose a Programming Language and Framework
#
# * Select a programming language that you're comfortable with and has good support for web development (e.g., Python, Java, Node.js).
# * Choose a web framework that provides a robust set of tools for building REST APIs (e.g., Flask, Django, Express.js).
#
# ...

# %%
## Detialed info to the LLM through System Message

from langchain.messages import SystemMessage, HumanMessage

system_msg =  SystemMessage(""" 
You are a senior Python developer with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but through in your explanations.""")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# **Creating a REST API**
# ...
#
# To create a REST API, you'll need to design the API endpoints, choose a framework, and implement the API using a programming language. Here, we'll use Python and the Flask framework.
#
# ### Step 1: Design the API Endpoints
#
#  Define the API endpoints, HTTP methods, and the data formats (e.g., JSON) for each endpoint. For example:
#
# | Endpoint | HTTP Method | Description |
# | --- | --- | --- |
# | `/users` | GET | Get all users |
# | `/users` | POST | Create a new user |
# | `/users/{id}` | GET | Get a user by ID |
# | `/users/{id}` | PUT | Update a user |
# | `/users/{id}` | DELETE | Delete a user |
#
# ### Step 2: Choose a Framework and Install Dependencies
#
# We'll use Flask, a lightweight Python web framework. Install Flask using pip:
# ```bash
# pip install flask
# ```
# ### Step 3: Implement the API
#
# Create a new Python file (e.g., `app.py`) and import Flask:
# ```python
# from flask import Flask, jsonify, request
#
# app = Flask(__name__)
# ...
